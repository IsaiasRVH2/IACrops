# %% [markdown]
# Para Ejecutar Conectarse al Colab y Correr la Primera Celda.

# %%
# !pip install dash
# !pip install dash-core-components
# !pip install dash-html-components
# !pip install dash-renderer
# !pip install plotly
# !pip install dash-bootstrap-components

#Librerias

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import dash_bootstrap_components as dbc

app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

costo_inicial = 1000
gastos_mantenimiento = 500
costo_final_venta = 3000
dias_estimados = 50

# Crear los datos para el gráfico predictivo
datos = {
    'Categoría': ['Costo Inicial', 'Gastos y Mantenimiento', 'Costo Final de Venta'],
    'Valor': [costo_inicial, gastos_mantenimiento, costo_final_venta]
}

# Crear el gráfico predictivo de barras
grafico_predictivo = dcc.Graph(
    id='ganancia-estimada',
    figure={
        'data': [
            {'x': datos['Categoría'], 'y': datos['Valor'], 'type': 'bar', 'name': 'Ganancia Estimada'}
        ],
        'layout': {
            'title': 'Ganancia Estimada del Agricultor',
            'yaxis': {'title': 'Valor en $'},
            'xaxis': {'title': 'Categoría'}
        }
    }
)

# Velocímetro de humedad del suelo
grafico_predictivo = dcc.Graph(
    id='ganancia-estimada',
    figure={
        'data': [
            {'x': datos['Categoría'], 'y': datos['Valor'], 'type': 'bar', 'name': 'Ganancia Estimada'}
        ],
        'layout': {
            'title': 'Ganancia Estimada del Agricultor',
            'yaxis': {'title': 'Valor en $'},
            'xaxis': {'title': 'Categoría'}
        }
    }
)

# Velocímetro de humedad del suelo sembrado
velocimetro_humedad_suelo = dcc.Graph(
    id='velocimetro-humedad-suelo',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 50,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Humedad del Suelo'},
            'gauge': {
                'axis': {'range': [0, 100]},
                'bar': {'color': 'lightblue'},
                'steps': [
                    {'range': [0, 20], 'color': 'red'},
                    {'range': [20, 40], 'color': 'orange'},
                    {'range': [40, 60], 'color': 'yellow'},
                    {'range': [60, 80], 'color': 'lightgreen'},
                    {'range': [80, 100], 'color': 'green'}
                ],
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de pH del suelo
velocimetro_ph_suelo = dcc.Graph(
    id='velocimetro-ph-suelo',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 7,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'pH del Suelo'},
            'gauge': {
                'axis': {'range': [4, 10]},
                'bar': {'color': 'lightblue'},
                'steps': [
                    {'range': [4, 5], 'color': 'red'},
                    {'range': [5, 7], 'color': 'orange'},
                    {'range': [7, 8], 'color': 'yellow'},
                    {'range': [8, 9], 'color': 'lightgreen'},
                    {'range': [9, 10], 'color': 'green'}
                ],
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de carbono del suelo
velocimetro_carbono_suelo = dcc.Graph(
    id='velocimetro-carbono-suelo',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 30,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Carbono del Suelo'},
            'gauge': {
                'axis': {'range': [10, 50]},
                'bar': {'color': 'lightblue'},
                'steps': [
                    {'range': [10, 20], 'color': 'red'},
                    {'range': [20, 30], 'color': 'orange'},
                    {'range': [30, 40], 'color': 'yellow'},
                    {'range': [40, 50], 'color': 'lightgreen'},
                ],
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de riego
velocimetro_riego = dcc.Graph(
    id='velocimetro-riego',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 36,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Riego'},
            'gauge': {
                'axis': {'range': [0, 72]},
                'bar': {'color': 'lightblue'},
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de sodio
velocimetro_sodio = dcc.Graph(
    id='velocimetro-sodio',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 70,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Sodio'},
            'gauge': {
                'axis': {'range': [40, 100]},
                'bar': {'color': 'lightblue'},
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de nitrato
velocimetro_nitrato = dcc.Graph(
    id='velocimetro-nitrato',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 80,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Nitrato'},
            'gauge': {
                'axis': {'range': [40, 120]},
                'bar': {'color': 'lightblue'},
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de fósforo
velocimetro_fosforo = dcc.Graph(
    id='velocimetro-fosforo',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 70,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Fósforo'},
            'gauge': {
                'axis': {'range': [40, 100]},
                'bar': {'color': 'lightblue'},
            }
        }],
        'layout': {'height': 200}
    }
)

# Velocímetro de potasio
velocimetro_potasio = dcc.Graph(
    id='velocimetro-potasio',
    figure={
        'data': [{
            'type': 'indicator',
            'mode': 'gauge+number',
            'value': 70,  # Valor inicial (podría ser cualquier valor dentro del rango)
            'title': {'text': 'Potasio'},
            'gauge': {
                'axis': {'range': [40, 100]},
                'bar': {'color': 'lightblue'},
            }
        }],
        'layout': {'height': 200}
    }
)

# Continuar con los otros velocímetros de datos de la misma manera

card_dias_estimados = dbc.Card(
    dbc.CardBody(
        [
            html.H4("Días Estimados para Cosechar = 50", className="card-title"),
            html.P("La estimacion de cosecha solo es una prediccion en base a el perido en el que se sembro y los cuidados recibidos"),
        ]
    ),
    className="mb-4",
)

velocimetros_row1 = dbc.Row([
    dbc.Col(velocimetro_humedad_suelo, width=3),
    dbc.Col(velocimetro_ph_suelo, width=3),
    dbc.Col(velocimetro_carbono_suelo, width=3),
    dbc.Col(velocimetro_riego, width=3),
], className="mb-4")

velocimetros_row2 = dbc.Row([
    dbc.Col(velocimetro_sodio, width=3),
    dbc.Col(velocimetro_nitrato, width=3),
    dbc.Col(velocimetro_fosforo, width=3),
    dbc.Col(velocimetro_potasio, width=3),
], className="mb-4")

# Layout del dashboard
app.layout = html.Div(
    style={'backgroundColor': '#10A51F'},  # Estilo de fondo personalizado
    children=[
        html.H1(children='Agricultura de Prescision', style={'color': 'white'}),



    velocimetros_row1,
    velocimetros_row2,

    # Gráfico predictivo de la ganancia estimada
    grafico_predictivo,

    # Velocímetros de datos

    card_dias_estimados,

    # Texto explicativo
    html.Div([
        html.H3('Tipo de Cosecha: '),
        html.P('Descripcion de la cosecha sembrada'),
    ], style={'margin-top': '50px'}),
])

if __name__ == '__main__':
    app.run_server(debug=True, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.1-py3-none-any.whl size=1014851 sha256=22d84e86e7c0865b7962485c7073fba87ed1a82ea4cebbf52b473c19a75b3c7c
#   Stored in directory: /root/.cache/pip/wheels/bd/b7/17/d60d18a7b3420135dfe0ce04d361b396f32b66b75a40471bb6
# Successfully built dash-renderer
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.2/221.2 kB 2.1 MB/s eta 0:00:00
# ...
# <ipython-input-1-0de80a6818c1>:11: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-1-0de80a6818c1>:12: UserWarning:
# The dash_html_components package is deprecated. Please replace
# ...
